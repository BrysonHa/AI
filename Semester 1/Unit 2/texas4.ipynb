# %% [markdown]
# # When drawing a card from a standard deck of cards, what is the probability that the card drawn is either a 5 or a 7? Assume no cards have been drawn initially.

# %% [markdown]
# This study will be a prospective, observational study. The sample space I am observing is all of the cards in a standard deck so 52. One trial of the simulation is dealing a card. I am measuring instances of a 5 or a 7 being dealt.

# %%
import seaborn, random, pandas

# %%
deck = range(1, 14)

numTrials = 100000000
hit = 0
miss = 0

for _ in range(numTrials):
    card = random.choice(deck)

    if card == 5 or card == 7:
        hit += 1
    else:
        miss += 1

odds = str(hit/numTrials*100)
print(odds+"%")
# Out:
# 15.386643999999999%

# %%
data = pandas.DataFrame({
    "Label": ["Miss", "Hit"],
    "Value": [miss, hit]
})

ax = seaborn.barplot(x="Label", y="Value", data=data)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:,}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', fontsize=10, color='black')
ax.text(0.95, 0.95, odds + "%",
        horizontalalignment='right',
        verticalalignment='top',
        transform=ax.transAxes,
        fontsize=12,
        color="red")
ax
# Out:
# <Axes: xlabel='Label', ylabel='Value'>

# %% [markdown]
# The empirical probabilty is 15.387% and the theorhetical probaility is 15.38%.
